# %%
import random
import nltk
import pandas as pd 
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem  import WordNetLemmatizer

# %%
spam  = pd.read_csv("SMSSpamCollection.txt", sep= '\t', names=["label", "message"])
spam.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
data_set = []
for index, row in spam.iterrows():
    data_set.append((row['message'], row['label']))

# %%
print(data_set[:5])
# Out:
# [('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...', 'ham'), ('Ok lar... Joking wif u oni...', 'ham'), ("Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", 'spam'), ('U dun say so early hor... U c already then say...', 'ham'), ("Nah I don't think he goes to usf, he lives around here though", 'ham')]

# %%
print(len(data_set))
# Out:
# 5572

# %% [markdown]
# ## preprocessing

# %%
stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def preprocess(document , stem='True'):
    '''change document to lowercase, removes stopwords and lemmatizes/stems the remainder of the sentence'''
    document = document.lower()
    words = word_tokenize(document)
    words = [word for word in words if word not in stopwords.words("english")]

    if stem: 
        words = [stemmer.stem(word) for word in words]
    else:
        words = [wordnet_lemmatizer.lemmatize(word, pos='v') for word in words]

    document = " ".join(words)
    return document

# %%
messages_set = []
for (message , label) in data_set:
    words_filtered  = [e.lower() for e in preprocess(message, stem=False).split() if len(e) >= 3]
    messages_set.append((words_filtered, label))

# %%
print(messages_set[:5])
# Out:
# [(['jurong', 'point', 'crazy', 'available', 'bugis', 'great', 'world', 'buffet', '...', 'cine', 'get', 'amore', 'wat', '...'], 'ham'), (['lar', '...', 'joke', 'wif', 'oni', '...'], 'ham'), (['free', 'entry', 'wkly', 'comp', 'win', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', '87121', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 'apply', '08452810075over18'], 'spam'), (['dun', 'say', 'early', 'hor', '...', 'already', 'say', '...'], 'ham'), (['nah', "n't", 'think', 'usf', 'live', 'around', 'though'], 'ham')]

# %% [markdown]
# ## preparing to create features

# %%
def get_words_in_messages(messages):
    all_words = []
    for (message,label) in messages:
        all_words.extend(message)
    return all_words

# %%
def get_word_features(wordList):

    wordList = nltk.FreqDist(wordList)
    word_features = wordList.keys()
    return word_features

# %%
word_features = get_word_features(get_words_in_messages(messages_set))
print(len(word_features))  # all unique words in the dataset
# Out:
# 7994

# %% [markdown]
# ## Preparing to create a train and test set

# %%
sliceIndex  = int((len(messages_set)*0.8))  # 80% of the data

# %%
random.shuffle(messages_set)  # shuffing the data so that no bias will occur

# %%
train_messages, test_messages = messages_set[:sliceIndex], messages_set[sliceIndex:]

# %%
len(train_messages)
# Out:
# 4457

# %%
len(test_messages)
# Out:
# 1115

# %% [markdown]
# ## Preparing to create feature maps for train and test data

# %%
def extract_features(document):
    document_words = set(document)
    features = {} 
    for word in word_features:
        features['contans(%s)' %word] = (word in document_words)
    return features

# %%
training_set = nltk.classify.apply_features(extract_features, train_messages)
testing_set = nltk.classify.apply_features(extract_features, test_messages)

# %%
print(training_set[:5])
# Out:
# [({'contans(jurong)': False, 'contans(point)': False, 'contans(crazy)': False, 'contans(available)': False, 'contans(bugis)': False, 'contans(great)': False, 'contans(world)': False, 'contans(buffet)': False, 'contans(...)': False, 'contans(cine)': False, 'contans(get)': False, 'contans(amore)': False, 'contans(wat)': False, 'contans(lar)': False, 'contans(joke)': False, 'contans(wif)': False, 'contans(oni)': False, 'contans(free)': False, 'contans(entry)': False, 'contans(wkly)': False, 'contans(comp)': False, 'contans(win)': False, 'contans(cup)': False, 'contans(final)': False, 'contans(tkts)': False, 'contans(21st)': False, 'contans(may)': False, 'contans(2005.)': False, 'contans(text)': False, 'contans(87121)': False, 'contans(receive)': False, 'contans(question)': False, 'contans(std)': False, 'contans(txt)': False, 'contans(rate)': False, 'contans(apply)': False, 'contans(08452810075over18)': False, 'contans(dun)': False, 'contans(say)': False, 'contans(early)': False, 'contans(hor)': False, 'contans(already)': False, 'contans(nah)': False, "contans(n't)": True, 'contans(think)': False, 'contans(usf)': False, 'contans(live)': False, 'contans(around)': False, 'contans(though)': False, 'contans(freemsg)': False, 'contans(hey)': False, 'contans(darling)': False, 'contans(week)': False, 'contans(word)': False, 'contans(back)': False, 'contans(like)': True, 'contans(fun)': False, 'contans(still)': False, 'contans(xxx)': False, 'contans(chgs)': False, 'contans(send)': False, 'contans(£1.50)': False, 'contans(rcv)': False, 'contans(even)': False, 'contans(brother)': False, 'contans(speak)': False, 'contans(treat)': False, 'contans(aid)': False, 'contans(patent)': False, 'contans(per)': False, 'contans(request)': False, "contans('melle)": False, 'contans(melle)': False, 'contans(oru)': False, 'contans(minnaminunginte)': False, 'contans(nurungu)': False, 'contans(vettam)': False, 'contans(set)': False, 'contans(callertune)': False, 'contans(callers)': False, 'contans(press)': False, 'contans(copy)': False, 'contans(friends)': False, 'contans(winner)': False, 'contans(value)': False, 'contans(network)': False, 'contans(customer)': False, 'contans(select)': False, 'contans(receivea)': False, 'contans(£900)': False, 'contans(prize)': False, 'contans(reward)': False, 'contans(claim)': False, 'contans(call)': False, 'contans(09061701461.)': False, 'contans(code)': False, 'contans(kl341)': False, 'contans(valid)': False, 'contans(hours)': False, 'contans(mobile)': False, 'contans(months)': False, 'contans(entitle)': False, 'contans(update)': False, 'contans(latest)': False, 'contans(colour)': False, 'contans(mobiles)': False, 'contans(camera)': False, 'contans(08002986030)': False, 'contans(gon)': False, 'contans(home)': False, 'contans(soon)': False, 'contans(want)': False, 'contans(talk)': False, 'contans(stuff)': False, 'contans(anymore)': False, 'contans(tonight)': False, "contans('ve)": False, 'contans(cry)': False, 'contans(enough)': False, 'contans(today)': False, 'contans(six)': False, 'contans(chance)': False, 'contans(cash)': False, 'contans(100)': False, 'contans(20,000)': False, 'contans(pound)': False, 'contans(csh11)': False, 'contans(87575.)': False, 'contans(cost)': False, 'contans(150p/day)': False, 'contans(6days)': False, 'contans(16+)': False, 'contans(tsandcs)': False, 'contans(reply)': False, 'contans(info)': False, 'contans(urgent)': False, 'contans(membership)': False, 'contans(£100,000)': False, 'contans(jackpot)': False, 'contans(81010)': False, 'contans(www.dbuk.net)': False, 'contans(lccltd)': False, 'contans(pobox)': False, 'contans(4403ldnw1a7rw18)': False, 'contans(search)': False, 'contans(right)': False, 'contans(thank)': False, 'contans(breather)': False, 'contans(promise)': False, 'contans(wont)': False, 'contans(take)': False, 'contans(help)': False, 'contans(grant)': False, 'contans(fulfil)': False, 'contans(wonderful)': False, 'contans(bless)': False, 'contans(time)': True, 'contans(date)': False, ...

# %%
print('training set size :  ', len(training_set))
print('testing set size :  ', len(testing_set))
# Out:
# training set size :   4457
# testing set size :   1115

# %% [markdown]
# ## Training

# %%
spamClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# ## Evaluation

# %%
print(nltk.classify.accuracy(spamClassifier, training_set))
# Out:
# 0.9930446488669509

# %%
print(nltk.classify.accuracy(spamClassifier, testing_set))
# Out:
# 0.9739910313901345

# %%
## Testing a example message with our newly trained classifier
m = 'CONGRATULATIONS!! As a valued account holder you have been selected to receive a £900 prize reward! Valid 12 hours only.'
print('Classification result : ', spamClassifier.classify(extract_features(m.split())))
# Out:
# Classification result :  spam

# %%
## Priting the most informative features in the classifier
print(spamClassifier.show_most_informative_features(50))
# Out:
# Most Informative Features
#          contans(urgent) = True             spam : ham    =    120.8 : 1.0
#             contans(txt) = True             spam : ham    =    117.4 : 1.0
#         contans(service) = True             spam : ham    =    107.6 : 1.0
#           contans(nokia) = True             spam : ham    =    105.9 : 1.0
#            contans(code) = True             spam : ham    =    101.7 : 1.0
#         contans(attempt) = True             spam : ham    =     80.9 : 1.0
#            contans(club) = True             spam : ham    =     68.5 : 1.0
#           contans(music) = True             spam : ham    =     68.5 : 1.0
#             contans(100) = True             spam : ham    =     64.3 : 1.0
#        contans(delivery) = True             spam : ham    =     64.3 : 1.0
#          contans(expire) = True             spam : ham    =     64.3 : 1.0
#        contans(landline) = True             spam : ham    =     63.5 : 1.0
# contans(congratulations) = True             spam : ham    =     60.2 : 1.0
#            contans(rate) = True             spam : ham    =     60.2 : 1.0
#       contans(statement) = True             spam : ham    =     56.0 : 1.0
#           contans(video) = True             spam : ham    =     56.0 : 1.0
#           contans(final) = True             spam : ham    =     51.9 : 1.0
#            contans(info) = True             spam : ham    =     51.9 : 1.0
#             contans(opt) = True             spam : ham    =     51.9 : 1.0
#          contans(latest) = True             spam : ham    =     50.7 : 1.0
#          contans(camera) = True             spam : ham    =     48.9 : 1.0
#            contans(quiz) = True             spam : ham    =     47.7 : 1.0
#          contans(mobile) = True             spam : ham    =     47.1 : 1.0
#        contans(customer) = True             spam : ham    =     44.7 : 1.0
#         contans(auction) = True             spam : ham    =     43.6 : 1.0
#          contans(reveal) = True             spam : ham    =     43.6 : 1.0
#           contans(pound) = True             spam : ham    =     41.8 : 1.0
#             contans(box) = True             spam : ham    =     39.4 : 1.0
#          contans(txting) = True             spam : ham    =     39.4 : 1.0
#            contans(draw) = True             spam : ham    =     36.8 : 1.0
#          contans(orange) = True             spam : ham    =     36.5 : 1.0
#          contans(select) = True             spam : ham    =     36.5 : 1.0
#            contans(comp) = True             spam : ham    =     35.3 : 1.0
#          contans(direct) = True             spam : ham    =     35.3 : 1.0
#          contans(reward) = True             spam : ham    =     35.3 : 1.0
#         contans(network) = True             spam : ham    =     33.9 : 1.0
#            contans(land) = True             spam : ham    =     33.6 : 1.0
#            contans(cash) = True             spam : ham    =     33.1 : 1.0
#           contans(apply) = True             spam : ham    =     31.1 : 1.0
#             contans(del) = True             spam : ham    =     31.1 : 1.0
#             contans(mat) = True             spam : ham    =     31.1 : 1.0
#        contans(motorola) = True             spam : ham    =     31.1 : 1.0
#        contans(sunshine) = True             spam : ham    =     31.1 : 1.0
#             contans(win) = True             spam : ham    =     29.0 : 1.0
#             contans(per) = True             spam : ham    =     28.9 : 1.0
#            contans(line) = True             spam : ham    =     27.3 : 1.0
#          contans(summer) = True             spam : ham    =     27.0 : 1.0
#            contans(user) = True             spam : ham    =     27.0 : 1.0
#       contans(currently) = True             spam : ham    =     26.2 : 1.0
#          contans(player) = True             spam : ham    =     26.2 : 1.0
# None

# %%
## storing the classifier on disk for later usage
import pickle
f = open('nb_spam_classifier.pickle', 'wb')
pickle.dump(spamClassifier,f)
print('Classifier stored at ', f.name)
f.close()
# Out:
# Classifier stored at  nb_spam_classifier.pickle
